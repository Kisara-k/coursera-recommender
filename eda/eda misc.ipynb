# %%
# Import required libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from wordcloud import WordCloud
import warnings

warnings.filterwarnings('ignore')
sns.set_style('whitegrid')
plt.rcParams['figure.figsize'] = (12, 6)

# Load the dataset
df = pd.read_csv('../data/courses.csv')
print(f"Shape: {df.shape}")
# Out:
# Shape: (5411, 8)

# %%
df.head(5)
# Out:
#                                                  url  \
# 0   https://www.coursera.org/learn/-network-security
# 1  https://www.coursera.org/learn/-security-princ...
# 2  https://www.coursera.org/learn/21st-century-en...
# 3  https://www.coursera.org/learn/360-vr-video-pr...
# 4  https://www.coursera.org/learn/3d-anatomy-phys...
#
#                                                 name  \
# 0                                   Network Security
# 1                                Security Principles
# 2  21st Century Energy Transition: how do we make...
# 3                        VR and 360 Video Production
# 4        Foundations of Human Anatomy and Physiology
#
#                            category  \
# 0            Information Technology
# 1            Information Technology
# 2  Physical Science And Engineering
# 3               Arts And Humanities
# 4                            Health
#
#                                       what_you_learn  \
# 0                                                NaN
# 1                                                NaN
# 2  Understand the complexity of systems supplying...
# 3                                                NaN
# 4  Learners will understand how body structure su...
#
#                                               skills language  \
# 0  Computer Networking, Network Planning And Desi...  English
# 1  Cyber Security Policies, Data Integrity, Cyber...  English
# 2  Electric Power Systems, Environmental Policy, ...  English
# 3  Virtual Reality, Videography, Media Production...  English
# 4  Vital Signs, Basic Patient Care, Anatomy, Heal...  English
#
#                                          instructors  \
# 0                                      ['~31081695']
# 1                                      ['~31081695']
# 2                                     ['brad-hayes']
# 3                                     ['googlearvr']
# 4  ['~167016541', '~166856472', '~166856442', '~1...
#
#                                              content
# 0  Welcome to course 4 of 5 of this Specializatio...
# 1  Welcome to course 1 of 5 of this Specializatio...
# 2  NOTE: “21 st Century Energy Transition – How d...
# 3  Welcome to the Google AR & VR Virtual Reality ...
# 4  This course provides a foundational understand...

# %%
df[df['name'].str.contains('learning', case=False)]
# Out:
#                                                     url  \
# 52    https://www.coursera.org/learn/active-learning...
# 76    https://www.coursera.org/learn/advanced-ai-and...
# 93    https://www.coursera.org/learn/advanced-deep-l...
# 94    https://www.coursera.org/learn/advanced-deep-l...
# 105   https://www.coursera.org/learn/advanced-learni...
# ...                                                 ...
# 5112  https://www.coursera.org/learn/ubiquitouslearning
# 5150  https://www.coursera.org/learn/unsupervised-al...
# 5151  https://www.coursera.org/learn/unsupervised-le...
# 5153  https://www.coursera.org/learn/uol-machine-lea...
# 5184  https://www.coursera.org/learn/using-generativ...
#
#                                                    name          category  \
# 52      Foundations for Active Learning in STEM Courses   Social Sciences
# 76    Advanced AI and Machine Learning Techniques an...  Computer Science
# 93    Advanced Deep Learning Techniques for Computer...      Data Science
# 94                           Deep Learning with PyTorch      Data Science
# 105                        Advanced Learning Algorithms      Data Science
# ...                                                 ...               ...
# 5112  Ubiquitous Learning and Instructional Technolo...   Social Sciences
# 5150        Unsupervised Algorithms in Machine Learning      Data Science
# 5151  Unsupervised Learning, Recommenders, Reinforce...      Data Science
# 5153                           Machine Learning for All  Computer Science
# 5184  Using Generative AI for Learning Design Activi...   Social Sciences
#
#                                          what_you_learn  \
# 52    Active learning strategies.\nActive learning s...
# 76                                                  NaN
# 93    Train and calibrate specialized models known a...
# 94    Key concepts on Softmax regression and underst...
# 105   Build and train a neural network with TensorFl...
# ...                                                 ...
# 5112                                                NaN
# 5150  Explain what unsupervised learning is, and lis...
# 5151  Use unsupervised learning techniques for unsup...
# 5153  You will understand the basic of how modern ma...
# 5184  Understand the key capabilities of generative ...
#
#                                                  skills language  \
# 52    Cooperation, Education Software and Technology...  English
# 76    Machine Learning Methods, Applied Machine Lear...  English
# 93    Medical Imaging, Deep Learning, Image Analysis...  English
# 94    PyTorch (Machine Learning Library), Supervised...  English
# 105   Tensorflow, Deep Learning, Machine Learning, S...  English
# ...                                                 ...      ...
# 5112  Innovation, Emerging Technologies, Artificial ...  English
# 5150  Statistical Analysis, Machine Learning, Scikit...  English
# 5151  Unsupervised Learning, Machine Learning, Artif...  English
# 5153  Computer Vision, Machine Learning Algorithms, ...  English
# 5184  Generative AI, Prompt Engineering, Brainstormi...  English
#
#                                             instructors  \
# 52    ['~184299955', '~36268133', '~97555527', 'jose...
# 76                                        ['microsoft']
# 93    ['~186909436', 'barmstro', '~154185359', '~343...
# 94                                        ['~28511493']
# 105   ['~170597538', 'andrewng', 'geoff-ladwig', '~7...
# ...                                                 ...
# 5112                      ['billcope', 'marykalantzis']
# 5150                                       ['geenakim']
# 5151  ['~170597538', 'andrewng', 'geoff-ladwig', '~7...
# 5153                                   ['marcogillies']
# 5184                         ['~33157001', '~22395627']
#
#                                                 content
# 52    This course is aimed a current or future educa...
# 76    This course explores advanced AI & ML techniqu...
# 93    Visual inspection and medical imaging are two ...
# 94    This course advances from fundamental machine ...
# 105   In the second course of the Machine Learning S...
# ...                                                 ...
# 5112  This course will analyze currently available t...
# 5150  One of the most useful areas in machine learni...
# 5151  In the third course of the Machine Learning Sp...
# 5153  Machine Learning, often called Artificial Inte...
# 5184  In “Using Generative AI for Learning Design Ac...
#
# [178 rows x 8 columns]

# %%
df[df['instructors'].str.contains('andrewng', case=False, na=False)]
# Out:
#                                                     url  \
# 105   https://www.coursera.org/learn/advanced-learni...
# 203      https://www.coursera.org/learn/ai-for-everyone
# 229   https://www.coursera.org/learn/ai-python-for-b...
# 1020  https://www.coursera.org/learn/convolutional-n...
# 1308  https://www.coursera.org/learn/deep-neural-net...
# 2087  https://www.coursera.org/learn/generative-ai-f...
# 2836  https://www.coursera.org/learn/introduction-to...
# 3157    https://www.coursera.org/learn/machine-learning
# 3176  https://www.coursera.org/learn/machine-learnin...
# 3544  https://www.coursera.org/learn/neural-networks...
# 3569  https://www.coursera.org/learn/nlp-sequence-mo...
# 5151  https://www.coursera.org/learn/unsupervised-le...
#
#                                                    name          category  \
# 105                        Advanced Learning Algorithms      Data Science
# 203                                     AI For Everyone          Business
# 229                             AI Python for Beginners  Computer Science
# 1020                      Convolutional Neural Networks      Data Science
# 1308  Improving Deep Neural Networks: Hyperparameter...      Data Science
# 2087                         Generative AI for Everyone      Data Science
# 2836                     Machine Learning in Production      Data Science
# 3157  Supervised Machine Learning: Regression and Cl...      Data Science
# 3176              Structuring Machine Learning Projects      Data Science
# 3544                  Neural Networks and Deep Learning      Data Science
# 3569                                    Sequence Models      Data Science
# 5151  Unsupervised Learning, Recommenders, Reinforce...      Data Science
#
#                                          what_you_learn  \
# 105   Build and train a neural network with TensorFl...
# 203                                                 NaN
# 229   Discover how Python can be applied in various ...
# 1020                                                NaN
# 1308                                                NaN
# 2087  What generative AI is and how it works, its co...
# 2836  Identify key components of the ML project life...
# 3157  Build machine learning models in Python using ...
# 3176                                                NaN
# 3544                                                NaN
# 3569                                                NaN
# 5151  Use unsupervised learning techniques for unsup...
#
#                                                  skills language  \
# 105   Tensorflow, Deep Learning, Machine Learning, S...  English
# 203   Deep Learning, Artificial Intelligence, Strate...  English
# 229   Jupyter, Data Analysis, Programming Principles...  English
# 1020  Artificial Intelligence and Machine Learning (...  English
# 1308  Artificial Neural Networks, Algorithms, Analys...  English
# 2087  Large Language Modeling, Generative AI, AI Pro...  English
# 2836  Data Pipelines, Continuous Monitoring, Data Qu...  English
# 3157  Statistical Modeling, Data Transformation, Jup...  English
# 3176  Debugging, Performance Tuning, Deep Learning, ...  English
# 3544  Machine Learning, Deep Learning, Calculus, Art...  English
# 3569  Deep Learning, Natural Language Processing, Py...  English
# 5151  Unsupervised Learning, Machine Learning, Artif...  English
#
#                                             instructors  \
# 105   ['~170597538', 'andrewng', 'geoff-ladwig', '~7...
# 203                                        ['andrewng']
# 229                                        ['andrewng']
# 1020        ['younes', 'andrewng', 'kian-katanforoosh']
# 1308        ['younes', 'andrewng', 'kian-katanforoosh']
# 2087                                       ['andrewng']
# 2836                                       ['andrewng']
# 3157  ['~170597538', 'andrewng', 'geoff-ladwig', '~7...
# 3176        ['younes', 'andrewng', 'kian-katanforoosh']
# 3544        ['younes', 'andrewng', 'kian-katanforoosh']
# 3569        ['younes', 'andrewng', 'kian-katanforoosh']
# 5151  ['~170597538', 'andrewng', 'geoff-ladwig', '~7...
#
#                                                 content
# 105   In the second course of the Machine Learning S...
# 203   AI is not only for engineers. If you want your...
# 229   AI Python for Beginners is designed to help yo...
# 1020  In the fourth course of the Deep Learning Spec...
# 1308  In the second course of the Deep Learning Spec...
# 2087  Instructed by AI pioneer Andrew Ng, Generative...
# 2836  In this Machine Learning in Production course,...
# 3157  In the first course of the Machine Learning Sp...
# 3176  In the third course of the Deep Learning Speci...
# 3544  In the first course of the Deep Learning Speci...
# 3569  In the fifth course of the Deep Learning Speci...
# 5151  In the third course of the Machine Learning Sp...

# %%
df[df['name'].str.contains(r'\bGo\b', case=True, na=False, regex=True)]
# Out:
#                                                     url  \
# 2208  https://www.coursera.org/learn/go-beyond-the-n...
# 2211  https://www.coursera.org/learn/golang-concurrency
# 2212  https://www.coursera.org/learn/golang-function...
# 2213  https://www.coursera.org/learn/golang-getting-...
# 3712  https://www.coursera.org/learn/packt-building-...
# 3714  https://www.coursera.org/learn/packt-burp-suit...
#
#                                                    name  \
# 2208  Go Beyond the Numbers: Translate Data into Ins...
# 2211                                  Concurrency in Go
# 2212           Functions, Methods, and Interfaces in Go
# 2213                            Getting Started with Go
# 3712                   Building Microservices API in Go
# 3714  Burp Suite Unfiltered - Go from a Beginner to ...
#
#                     category  \
# 2208            Data Science
# 2211        Computer Science
# 2212        Computer Science
# 2213        Computer Science
# 3712        Computer Science
# 3714  Information Technology
#
#                                          what_you_learn  \
# 2208  Apply the exploratory data analysis (EDA) proc...
# 2211                                                NaN
# 2212                                                NaN
# 2213                                                NaN
# 3712  Create modular and reusable code with Go modul...
# 3714  Install and configure a web security testing l...
#
#                                                  skills language  \
# 2208  Data Transformation, Python Programming, Explo...  English
# 2211  Algorithms, System Programming, OS Process Man...  English
# 2212  Software Design, Functional Design, Go (Progra...  English
# 2213  Development Environment, Programming Principle...  English
# 3712  API Design, Go (Programming Language), Web Ser...  English
# 3714  Vulnerability Scanning, Cyber Security Assessm...  English
#
#                          instructors  \
# 2208  ['google-career-certificates']
# 2211                   ['ianharris']
# 2212                   ['ianharris']
# 2213                   ['ianharris']
# 3712                  ['~158375127']
# 3714                  ['~158375127']
#
#                                                 content
# 2208  This is the third of eight courses in the Goog...
# 2211  Learn how to implement concurrent programming ...
# 2212  Continue your exploration of the Go programmin...
# 2213  Learn the basics of Go, an open source program...
# 3712  Updated in May 2025.This course now features C...
# 3714  Updated in May 2025.This course now features C...
